# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # READ RESULTS DATA

# %%
result_path = './results/fixed_eaves'
if os.path.exists(result_path) == False:
    exit(0)
num_of_scenarios = len(os.listdir(result_path))

GD_results = [0 for i in range(num_of_scenarios)]
PSO_results = [0 for i in range(num_of_scenarios)]
GA_results = [0 for i in range(num_of_scenarios)]
PSO_GD_results = [0 for i in range(num_of_scenarios)]
GA_GD_results = [0 for i in range(num_of_scenarios)]

num_of_run = [0 for i in range(num_of_scenarios)]
for scenario in os.listdir(result_path):
    path = result_path + '/' + scenario
    for run in os.listdir(path):
        num_of_user = int(scenario.split('u')[0])
        if (num_of_user > 10):
            continue
        i = num_of_user - 1
        
        gd = np.load(path + '/' + run + '/' + 'GD_results.npy')
        pso = np.load(path + '/' + run + '/' + 'PSO_results.npy')
        ga = np.load(path + '/' + run + '/' + 'GA_results.npy')
        pso_gd = np.load(path + '/' + run + '/' + 'PSO_GD_results.npy')
        GD_results[i] += gd[-1]
        PSO_results[i] += pso[-1]
        GA_results[i] += ga[-1]
        PSO_GD_results[i] += pso_gd[-1]
        num_of_run[i] += 1
    

print('GD:', GD_results)
print('PSO:', PSO_results)
print('GA:', GA_results)
print('PSO_GD:', PSO_GD_results)
print('num_of_run:', num_of_run)
for i in range(num_of_scenarios):
    GD_results[i] /= num_of_run[i]
    PSO_results[i] /= num_of_run[i]
    GA_results[i] /= num_of_run[i]
    PSO_GD_results[i] /= num_of_run[i]
    #GA_GD_results[i] /= num_of_run[i]
# Out:
# GD: [7.643036994247873, 12.071411673133014, 34.644843435025386, 590.254487590712, 389.613060200566, 322.6758144457536, 138.14107761927926, 144.7850474396712, 255.22607147885216, 76.70358183703829]
# PSO: [17.19983357581591, 29.232870406116213, 29.83270017379093, 427.97192721537635, 428.5557821629896, 345.50206955005535, 140.42469336121377, 131.85228912715354, 230.9019605948193, 70.86722089150652]
# GA: [10.613197460051888, 16.758349209426626, 18.148802791135406, 412.0244222113307, 414.37806485451364, 385.2514280997933, 189.094760953619, 187.48428495044686, 252.85933124551772, 80.5913641135285]
# PSO_GD: [17.939621780773212, 31.929731402373594, 43.67787177030286, 1180.0757972646932, 1210.085132378148, 908.0597606250192, 361.22282135837236, 328.6227657219991, 492.4842379525411, 146.20511536355627]
# num_of_run: [1, 1, 1, 20, 20, 20, 10, 10, 19, 6]

# %% [markdown]
# # PLOT

# %%
plt.xlabel('Number of users')
plt.ylabel('Secrecy Rate (bps/Hz)')
plt.yscale
plt.title('Fixed 3 eaves')
#plt.plot([i for i in range(4, 11)], GD_results, label='GD')
plt.plot([i for i in range(1, 11)], PSO_results, label='PSO')
plt.plot([i for i in range(1, 11)], GA_results, label='GA')
plt.plot([i for i in range(1, 11)], PSO_GD_results, label='PSO_GD')
print(PSO_GD_results)
#plt.plot(GA_GD_results, label='GA_GD')
plt.legend()
plt.show()
print(PSO_GD_results[-1])
# Out:
# [17.939621780773212, 31.929731402373594, 43.67787177030286, 59.00378986323466, 60.504256618907405, 45.402988031250956, 36.12228213583724, 32.86227657219991, 25.920223050133743, 24.36751922725938]
# 24.36751922725938

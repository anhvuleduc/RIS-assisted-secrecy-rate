# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # READ RESULTS DATA

# %%
result_path = './results/fixed_eaves'
if os.path.exists(result_path) == False:
    exit(0)
num_of_scenarios = len(os.listdir(result_path))

GD_results = [0 for i in range(num_of_scenarios)]
PSO_results = [0 for i in range(num_of_scenarios)]
GA_results = [0 for i in range(num_of_scenarios)]
PSO_GD_results = [0 for i in range(num_of_scenarios)]
GA_GD_results = [0 for i in range(num_of_scenarios)]

num_of_run = [0 for i in range(num_of_scenarios)]
for scenario in os.listdir(result_path):
    path = result_path + '/' + scenario
    for run in os.listdir(path):
        num_of_user = int(scenario.split('u')[0])
        if (num_of_user > 10):
            continue
        i = num_of_user - 4
        
        gd = np.load(path + '/' + run + '/' + 'GD_results.npy')
        pso = np.load(path + '/' + run + '/' + 'PSO_results.npy')
        ga = np.load(path + '/' + run + '/' + 'GA_results.npy')
        pso_gd = np.load(path + '/' + run + '/' + 'PSO_GD_results.npy')
        GD_results[i] += gd[-1]
        PSO_results[i] += pso[-1]
        GA_results[i] += ga[-1]
        PSO_GD_results[i] += pso_gd[-1]
        num_of_run[i] += 1
    

print('GD:', GD_results)
print('PSO:', PSO_results)
print('GA:', GA_results)
print('PSO_GD:', PSO_GD_results)
print('num_of_run:', num_of_run)
for i in range(num_of_scenarios):
    GD_results[i] /= num_of_run[i]
    PSO_results[i] /= num_of_run[i]
    GA_results[i] /= num_of_run[i]
    PSO_GD_results[i] /= num_of_run[i]
    #GA_GD_results[i] /= num_of_run[i]
# Out:
# GD: [np.float64(590.254487590712), np.float64(284.97105365344095), np.float64(322.67581444575364), np.float64(138.14107761927926), np.float64(144.7850474396712), np.float64(245.45288807972724), np.float64(64.66527847991544)]
# PSO: [np.float64(427.9719272153764), np.float64(320.1312969862028), np.float64(345.5020695500554), np.float64(140.42469336121377), np.float64(131.85228912715354), np.float64(219.3539760575094), np.float64(58.57099014370536)]
# GA: [np.float64(412.0244222113306), np.float64(310.14490405486225), np.float64(385.2514280997933), np.float64(189.09476095361904), np.float64(187.48428495044686), np.float64(242.56322363693695), np.float64(62.485725679628985)]
# PSO_GD: [np.float64(1180.0757972646932), np.float64(918.6509283463623), np.float64(908.0597606250192), np.float64(361.2228213583724), np.float64(328.62276572199903), np.float64(473.92075750431275), np.float64(130.8551539248219)]
# num_of_run: [20, 15, 20, 10, 10, 18, 5]

# %% [markdown]
# # PLOT

# %%
plt.xlabel('Number of users')
plt.ylabel('Secrecy Rate (bps/Hz)')
plt.yscale
plt.title('Fixed 3 eaves')
#plt.plot([i for i in range(4, 11)], GD_results, label='GD')
plt.plot([i for i in range(4, 11)], PSO_results, label='PSO')
plt.plot([i for i in range(4, 11)], GA_results, label='GA')
plt.plot([i for i in range(4, 11)], PSO_GD_results, label='PSO_GD')
print(PSO_GD_results)
#plt.plot(GA_GD_results, label='GA_GD')
plt.legend()
plt.show()
print(PSO_GD_results[-1])
# Out:
# [np.float64(59.00378986323466), np.float64(61.24339522309082), np.float64(45.402988031250956), np.float64(36.12228213583724), np.float64(32.8622765721999), np.float64(26.32893097246182), np.float64(26.17103078496438)]
# 26.17103078496438
